# %%
1+1
# Out:
# 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

print("Setup Complete")
# Out:
# Setup Complete

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles:")
print(os.listdir())
# Out:
# Current Folder:
# C:\Users\jashw\Documents\Marketing_Campaign_EDA
#
# Files:
# ['.ipynb_checkpoints', 'Marketing_EDA.ipynb.ipynb', 'Untitled.ipynb']
